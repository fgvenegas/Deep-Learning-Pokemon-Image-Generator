# %%
import imgaug as ia
import numpy as np
import os
from tqdm import tqdm
from skimage import io, transform
from scipy import misc
import matplotlib.pyplot as plt
from imgaug import augmenters as iaa
import cv2

# %matplotlib inline

# %% [markdown]
# # First open database and apply data augmentation

# %%
import io
import requests
from PIL import Image
from torchvision import models, transforms
from torch.autograd import Variable

# %%
normalize = transforms.Normalize(
   mean=[0.485, 0.456, 0.406],
   std=[0.229, 0.224, 0.225]
)

preprocess = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

# %%
response = requests.get('https://www.serebii.net/art/th/1.png')
img_pil = Image.open(io.BytesIO(response.content))

# %%
img_pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=140x130 at 0x1027FA2E8>

# %%
img_tensor = preprocess(img_pil)
img_tensor.unsqueeze_(0)
img_variable = Variable(img_tensor)

# %%
print(img_variable)
# Out:
# Variable containing:
# (0 ,0 ,.,.) =
#   0.5922  0.5961  0.6039  ...   0.7451  0.3922  0.3725
#   0.5922  0.5961  0.6039  ...   0.7412  0.5451  0.2980
#   0.5961  0.6039  0.6039  ...   0.7451  0.6275  0.2431
#            ...             ⋱             ...
#   0.7843  0.7843  0.7843  ...   0.4941  0.4431  0.2627
#   0.7843  0.7843  0.7843  ...   0.2824  0.1333  0.2863
#   0.7804  0.7529  0.6980  ...   0.2549  0.3843  0.4824
#
# (0 ,1 ,.,.) =
#   0.8118  0.8157  0.8196  ...   0.2471  0.1686  0.5725
#   0.8118  0.8157  0.8196  ...   0.2471  0.1882  0.4235
#   0.8157  0.8157  0.8196  ...   0.2510  0.2196  0.3020
#            ...             ⋱             ...
#   0.6078  0.6078  0.6078  ...   0.7020  0.6314  0.3647
#   0.6078  0.6078  0.6078  ...   0.3961  0.1804  0.4000
#   0.6039  0.5843  0.5412  ...   0.3765  0.5922  0.7020
#
# (0 ,2 ,.,.) =
#   0.6980  0.7020  0.7020  ...   0.3059  0.1961  0.5098
#   0.6980  0.7020  0.7020  ...   0.3098  0.2314  0.3922
#   0.7020  0.7020  0.7020  ...   0.3098  0.2706  0.2863
#            ...             ⋱             ...
#   0.7176  0.7176  0.7176  ...   0.6078  0.5451  0.3216
#   0.7176  0.7176  0.7176  ...   0.3490  0.1686  0.3529
#   0.7176  0.6902  0.6431  ...   0.3490  0.5373  0.6078
#
# (0 ,3 ,.,.) =
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#            ...             ⋱             ...
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
# [torch.FloatTensor of size 1x4x32x32]

# %%
import torchvision.datasets as dset
import torchvision.transforms as transforms

# %%
dataset = dset.ImageFolder(root='.',
       transform=transforms.Compose([
       transforms.Scale(size=[64,64]),
       transforms.RandomCrop(32, padding=4),
       transforms.RandomHorizontalFlip(),
       transforms.ToTensor(),
]))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-edd4bd96a7d2> in <module>()
#       4        transforms.RandomCrop(32, padding=4),
#       5        transforms.RandomHorizontalFlip(),
# ----> 6        transforms.ToTensor(),
#       7 ]))
#
# /usr/local/lib/python3.6/site-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader)
#      95         if len(imgs) == 0:
#      96             raise(RuntimeError("Found 0 images in subfolders of: " + root + "\n"
# ---> 97                                "Supported image extensions are: " + ",".join(IMG_EXTENSIONS)))
#      98
#      99         self.root = root
#
# RuntimeError: Found 0 images in subfolders of: .
# Supported image extensions are: .jpg,.JPG,.jpeg,.JPEG,.png,.PNG,.ppm,.PPM,.bmp,.BMP

# %%
dataloader = torch.utils.data.DataLoader(dataset, batch_size=64,
                                         shuffle=True, num_workers=int(3))

# %%
len(dataloader)
# Out:
# 13
